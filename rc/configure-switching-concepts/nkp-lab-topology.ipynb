# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-practice-labs/blob/main/README.md) >
#
# ## CompTIA Network+ Practice Labs
# ###### Topic: ``Lab Topology``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Lab Topology](#LabTopology)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LabTopology"></a>
# ***
# ###### Lab Topology
# ***

# %% [markdown]
# Cisco lab diagram:
#
# x3 switches:
#
# - ``NYCORE1``
#
#
# - ``NYCORE2``
#
#
# - ``NYACCESS1``
#
#
# x3 routers:
#
#
# - ``NYEDGE1``
#
#
# - ``NYEDGE2``
#
#
# - ``NYWAN1``

# %% [markdown]
# The switches are connected together in a ring, with ``NYCORE1`` and ``NYCORE2`` being connected together with two links.

# %% [markdown]
# The three routers are also connected in a ring via their serial interfaces.

# %% [markdown]
# - ``NYEDGE1`` (Cisco 2911 Router)
#
#
# - ``NYEDGE2`` (Cisco 2911 Router)
#
#
# - ``NYCORE1`` (Cisco 3750v2-24PS Switch)
#
#
# - ``NYCORE2`` (Cisco 3750v2-24PS Switch)
#
#
# - ``NYACCESS1`` (Cisco 2960-24 Switch)
#
#
# - ``NYWAN1`` (Cisco 2911 Router)
#
#
# - ``PLABCSCO01`` (Cisco Tools Server)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;CompTIA Network+ Practice Lab (N10-007)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
